# %%
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
digits = datasets.load_digits()
# print(digits.data.shape)
# # plt.gray()
# print(len(digits.images))
# # for i in range(1):
# #     plt.matshow(digits.images[i])

# #     plt.show
# X_digits= digits.data
# print(len(X_digits[:10 ]))
# Y_digits = digits.target
# print(Y_digits[:10]
estimator = KNeighborsClassifier()

estimator.fit(digits.data[:100],digits.target[:100])



estimated = estimator.predict(digits.data[150:160])

for i in range(10,20):
    plt.title('real value '+str(digits.target[i]) +'___'+'estimated value'+ str(estimated[i-10]))
    plt.matshow(digits.images[i])

# %%
def DigitsClassification():
    digits = datasets.load_digits()
#     print(digits.data.shape)
#    plt.gray()
#     print(len(digits.images))
#     for i in range(1):
#         plt.matshow(digits.images[i])
#         plt.show
    X_digits= digits.data
    Y_digits = digits.target
#     print(digits.target)
#     print(digits.data)
    n_samples = len(X_digits)

    X_train = X_digits[:10 ]
    Y_train = Y_digits[:10 ]
    knn = KNeighborsClassifier()
    knn.fit(X_train,Y_train)
    X_test = X_digits[99]
    plt.matshow(digits.images[99])
    plt.title(' digits dataset ')
#     plt.annotate('~~~~~~DR.SAVEALIFT DRAN~~~~',xy=(0,7),xytest=(1,1),color='green',style='oblique')
    plt.show()
    y_test = Y_digits[99]
    print ("actual class is "+ str(y_test))
    X_test.reshape(1,-1)
    print(X_test)
    
    print ("predicted class is "+ str(knn.predict(X_test)))
    
DigitsClassification()
# Out:
# actual class is 1
# [ 0.  0.  1. 15. 13.  0.  0.  0.  0.  0.  1. 16. 16.  5.  0.  0.  0.  0.
#   7. 16. 16.  0.  0.  0.  0.  0. 13. 16. 13.  0.  0.  0.  0.  7. 16. 16.
#  13.  0.  0.  0.  0.  1. 11. 16. 13.  0.  0.  0.  0.  0.  2. 16. 16.  0.
#   0.  0.  0.  0.  1. 14. 16.  3.  0.  0.]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-f7df64d49d5d> in <module>
#      29     print ("predicted class is "+ str(knn.predict(X_test)))
#      30
# ---> 31 DigitsClassification()
#
# <ipython-input-27-f7df64d49d5d> in DigitsClassification()
#      27     print(X_test)
#      28
# ---> 29     print ("predicted class is "+ str(knn.predict(X_test)))
#      30
#      31 DigitsClassification()
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     145             Class labels for each data sample.
#     146         """
# ...

# %%
from skimage import *
image = data.coins() # or any NumPy array!
io.imshow(image)
edges = filters.sobel(image)
io.imshow(edges)

# %%
import numpy as np
import matplotlib.pyplot as plt
# Load a small section of the image.
image = data.coins()[0:95, 70:370]
fig, axes = plt.subplots(ncols=2, nrows=3,figsize=(8, 4))

ax0, ax1, ax2, ax3, ax4, ax5 = axes.flat
ax0.imshow(image, cmap=plt.cm.gray)
ax0.set_title('Original', fontsize=24)
ax0.axis('off')

values, bins = np.histogram(image,
bins=np.arange(256))
ax1.plot(bins[:-1], values, lw=2, c='k')
ax1.set_xlim(xmax=256)
ax1.set_yticks([0, 400])
ax1.set_aspect(.2)
ax1.set_title('Histogram', fontsize=24)

# Apply threshold.
from skimage.filters import threshold_adaptive
bw = threshold_adaptive(image, 95, offset=-15)
ax2.imshow(bw, cmap=plt.cm.gray)
ax2.set_title('Adaptive threshold', fontsize=24)
ax2.axis('off')

# Find maxima.
from skimage.feature import peak_local_max
coordinates = peak_local_max(image, min_distance=20)
ax3.imshow(image, cmap=plt.cm.gray)
ax3.autoscale(False)
ax3.plot(coordinates[:, 1],
coordinates[:, 0], c='r.')
ax3.set_title('Peak local maxima', fontsize=24)
ax3.axis('off')
# Out:
# C:\Users\feria\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# C:\Users\feria\Anaconda3\lib\site-packages\skimage\filters\thresholding.py:229: skimage_deprecation: Function ``threshold_adaptive`` is deprecated and will be removed in version 0.15. Use ``threshold_local`` instead.
#   def threshold_adaptive(image, block_size, method='gaussian', offset=0,
# C:\Users\feria\Anaconda3\lib\site-packages\skimage\filters\thresholding.py:231: UserWarning: The return value of `threshold_local` is a threshold image, while `threshold_adaptive` returned the *thresholded* image.
#   warn('The return value of `threshold_local` is a threshold image, while '
# (-0.5, 299.5, 94.5, -0.5)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000002905B03D730> (for post_execute):
# ...

# %%
digits = datasets.load_digits()
digits.images.shape

import matplotlib.pyplot as plt
plt.imshow(digits.images[-1], cmap=plt.cm.gray_r)


data= digits.images.reshape((digits.images.shape[0], -1))
estimator = KNeighborsClassifier()

estimator.fit(data,digits.data)
x_test = digits.images[0:10].reshape(-1,1)
estimator.predict(digits.images[0:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-7618f9cc7eba> in <module>
#      11 estimator.fit(data,digits.data)
#      12 x_test = digits.images[0:10].reshape(-1,1)
# ---> 13 estimator.predict(digits.images[0:10])
#      14
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     145             Class labels for each data sample.
#     146         """
# --> 147         X = check_array(X, accept_sparse='csr')
#     148
#     149         neigh_dist, neigh_ind = self.kneighbors(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     568         if not allow_nd and array.ndim >= 3:
# ...
